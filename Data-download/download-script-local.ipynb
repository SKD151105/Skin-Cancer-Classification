# %%
import pandas as pd

# Adjust path if needed
metadata = pd.read_csv(r'C:\Users\ompat\OneDrive\Desktop\mini_proj_data\HAM10000_metadata.csv')

# Check what columns you have
print(metadata.columns)
# Out:
# Index(['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization'], dtype='object')

# %%
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
print(metadata['image_id'].head())
# Out:
# 0    ISIC_0027419
# 1    ISIC_0025030
# 2    ISIC_0026769
# 3    ISIC_0025661
# 4    ISIC_0031633
# Name: image_id, dtype: object

# %%
# Function to get the correct path for each image
def resolve_path(image_id):
    fname = f"{image_id}.jpg"
    if (part1_dir / fname).exists():
        return str(part1_dir / fname)
    elif (part2_dir / fname).exists():
        return str(part2_dir / fname)
    else:
        return None

# %%
sample_id = metadata['image_id'].iloc[0]
print("Sample ID:", sample_id)
print("Resolved path:", resolve_path(sample_id))
# Out:
# Sample ID: ISIC_0027419
# Resolved path: C:\Users\ompat\OneDrive\Desktop\mini_proj_data\HAM10000_images_part_1\ISIC_0027419.jpg

# %%
from pathlib import Path

# Paths to the two image folders
part1_dir = Path('C:/Users/ompat/OneDrive/Desktop/mini_proj_data/HAM10000_images_part_1')
part2_dir = Path('C:/Users/ompat/OneDrive/Desktop/mini_proj_data/HAM10000_images_part_2')



metadata['image_path'] = metadata['image_id'].apply(resolve_path)

# Drop rows if any images are missing
metadata = metadata.dropna(subset=['image_path'])

# Verify
metadata['image_path']
# Out:
# 0        C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 1        C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 2        C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 3        C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 4        C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
#                                ...
# 10010    C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 10011    C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 10012    C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 10013    C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# 10014    C:\Users\ompat\OneDrive\Desktop\mini_proj_data...
# Name: image_path, Length: 10015, dtype: object

# %%
print(r"C:\Users\ompat\OneDrive\Desktop\mini_proj_data\HAM10000_images_part_1\ISIC_0024306.jpg")
# Out:
# C:\Users\ompat\OneDrive\Desktop\mini_proj_data\HAM10000_images_part_1\ISIC_0024306.jpg

# %%
metadata
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#                                               image_path
# ...

# %%
metadata.to_csv(r'C:\Users\ompat\OneDrive\Desktop\mini_proj_data\proj_metadata.csv', index=False)
