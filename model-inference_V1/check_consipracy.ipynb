# %% [markdown]
# <a href="https://colab.research.google.com/github/SKD151105/Skin-Cancer-Classification/blob/main/model-inference_V1/check_consipracy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/mini_proj_data/HAM10000/hmnist_28_28_RGB.csv')
df.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# ...

# %%
df
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0            192        153        193        195        155        192
# 1             25         14         30         68         48         75
# 2            192        138        153        200        145        163
# 3             38         19         30         95         59         72
# 4            158        113        139        194        144        174
# ...          ...        ...        ...        ...        ...        ...
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/mini_proj_data/HAM10000/HAM10000_metadata.csv')
df2.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
df2
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
# [10015 rows x 7 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4086958859.py in <cell line: 0>()
# ----> 1 df2.counts()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'counts'

# %%
print("Distribution of label counts in df:")
display(df['label'].value_counts())

print("\nDistribution of dx counts in df2:")
display(df2['dx'].value_counts())
# Out:
# Distribution of label counts in df:
# label
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: count, dtype: int64
# Distribution of dx counts in df2:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %% [markdown]
# # Task
# Compare the pixel values in `df` with the actual image pixel values for a sample image from `df2`.

# %% [markdown]
# ## Identify a sample image
#
# ### Subtask:
# Select a row from `df2` and note its `image_id`.

# %% [markdown]
# **Reasoning**:
# Select a row from df2 and extract the image_id from that row.

# %%
sample_row_index = 0
sample_image_id = df2.loc[sample_row_index, 'image_id']
print(f"Selected image_id: {sample_image_id}")
# Out:
# Selected image_id: ISIC_0027419

# %% [markdown]
# ## Load the corresponding image
#
# ### Subtask:
# Load the actual image file using the `image_id` obtained from the previous step.

# %% [markdown]
# **Reasoning**:
# Construct the image file path, import the PIL library, and open the image file.

# %%
import PIL.Image

image_path = f'/content/drive/MyDrive/mini_proj_data/HAM10000/HAM10000_images_rgb/{sample_image_id}.jpg'
img = PIL.Image.open(image_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3156356769.py in <cell line: 0>()
#       2
#       3 image_path = f'/content/drive/MyDrive/mini_proj_data/HAM10000/HAM10000_images_rgb/{sample_image_id}.jpg'
# ----> 4 img = PIL.Image.open(image_path)
#
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3511     if is_path(fp):
#    3512         filename = os.fspath(fp)
# -> 3513         fp = builtins.open(filename, "rb")
#    3514         exclusive_fp = True
#    3515     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/mini_proj_data/HAM10000/HAM10000_images_rgb/ISIC_0027419.jpg'

# %% [markdown]
# **Reasoning**:
# The previous command failed because the image file was not found at the specified path. I need to check if the directory exists and if the file is present in that directory.

# %%
import os

image_directory = '/content/drive/MyDrive/mini_proj_data/HAM10000/HAM10000_images/'
if not os.path.exists(image_directory):
    print(f"Image directory not found: {image_directory}")
else:
    image_path = os.path.join(image_directory, f'{sample_image_id}.jpg')
    if not os.path.exists(image_path):
        print(f"Image file not found: {image_path}")
    else:
        img = PIL.Image.open(image_path)
        print(f"Image file found and opened: {image_path}")
